# %% [markdown]
# <a href="https://colab.research.google.com/github/160902/data-analitik_praktik/blob/main/vitojuandabanipraktikbigdataanaltik.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
plt.axis([0,10,0,25])
# Out:
# (0.0, 10.0, 0.0, 25.0)

# %%
plt.plot([2,2.5,6,7,9],[4,11,14,17,24],'gs')
plt.show()

# %%
plt.plot([2,2.5,6,7,9],[4,11,14,17,24])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([2,3,4,5],[3,8,10,12])
plt.xlabel('actual birth weight')
plt.ylabel('estimated birth weight')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

#memanggil data set

dataset= pd.read_csv('data3.csv')

# %%
dataset.keys()
# Out:
# Index(['Nilai UTS', 'Nilai UAS '], dtype='object')

# %%
dataset.shape
# Out:
# (14, 2)

# %%
from ast import increment_lineno
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
insurance = 'insurance.csv'
insurance_data = pd.read_csv(insurance)
insurance_data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['expenses'])
# Out:
# <Axes: xlabel='bmi', ylabel='expenses'>

# %%
sns.regplot(x=insurance_data['bmi'], y=insurance_data['expenses'])
# Out:
# <Axes: xlabel='bmi', ylabel='expenses'>

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['expenses'], hue=insurance_data['smoker'])
# Out:
# <Axes: xlabel='bmi', ylabel='expenses'>

# %%
sns.lmplot(x='bmi', y='expenses', hue='smoker', data = insurance_data)
